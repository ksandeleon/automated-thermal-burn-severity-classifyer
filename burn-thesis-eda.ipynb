# %%
import os

dataset_dir = 'dataset-v2/kaggle-good/archive'

ds = [f for f in os.listdir(dataset_dir) if os.path.isfile(os.path.join(dataset_dir, f)) and not f.startswith('.')]

# Print total number of images
print(f"Total number of dataset (image + txt): {len(ds)}")
# Out:
# Total number of dataset (image + txt): 2448

# %%
import os
from collections import Counter


label_dir = dataset_dir
class_counts = Counter()

for label_file in os.listdir(label_dir):
    if label_file.endswith('.txt'):
        with open(os.path.join(label_dir, label_file), 'r') as f:
            first_line = f.readline()
            if first_line:
                class_id = first_line.strip().split()[0]
                class_counts[class_id] += 1

class_map = {'0': 'First Degree Burn', '1': 'Second Degree Burn', '2': 'Third Degree Burn'}

print("Class Distribution (one label per image):")
for class_id, count in class_counts.items():
    print(f"{class_map.get(class_id, 'Unknown')} (Class {class_id}): {count} images")

total_labeled = sum(class_counts.values())
print(f"\nTotal labeled images: {total_labeled}")
# Out:
# Class Distribution (one label per image):
# First Degree Burn (Class 0): 532 images
# Second Degree Burn (Class 1): 488 images
# Third Degree Burn (Class 2): 201 images
#
# Total labeled images: 1221

# %%
# Check how many label files have no corresponding image
image_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if f.endswith('.jpg') or f.endswith('.png'))
label_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if f.endswith('.txt'))

no_image = label_stems - image_stems
print(f"Label files with no matching image: {len(no_image)}")
if no_image:
    print("Example:", list(no_image)[:5])

no_label = image_stems - label_stems
print(f"Image files with no matching label: {len(no_label)}")
if no_label:
    print("Example:", list(no_label)[:5])
# Out:
# Label files with no matching image: 0
# Image files with no matching label: 4
# Example: ['img1228', 'img589', 'img460', 'img357']

# %%
image_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if f.endswith('.jpg') or f.endswith('.png'))
label_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if f.endswith('.txt'))

no_image = label_stems - image_stems

print(f"Deleting {len(no_image)} label files with no matching image...")
for stem in no_image:
    label_path = os.path.join(dataset_dir, stem + '.txt')
    if os.path.exists(label_path):
        os.remove(label_path)
        print(f"Deleted: {label_path}")
print("Done.")
# Out:
# Deleting 216 label files with no matching image...
# Deleted: dataset-v2/kaggle-good/archive\img912.txt
# Deleted: dataset-v2/kaggle-good/archive\img1053.txt
# Deleted: dataset-v2/kaggle-good/archive\img1034.txt
# Deleted: dataset-v2/kaggle-good/archive\img754.txt
# Deleted: dataset-v2/kaggle-good/archive\img1339.txt
# Deleted: dataset-v2/kaggle-good/archive\img1102.txt
# Deleted: dataset-v2/kaggle-good/archive\img1135.txt
# Deleted: dataset-v2/kaggle-good/archive\img1329.txt
# Deleted: dataset-v2/kaggle-good/archive\img747.txt
# Deleted: dataset-v2/kaggle-good/archive\img860.txt
# Deleted: dataset-v2/kaggle-good/archive\img940.txt
# Deleted: dataset-v2/kaggle-good/archive\img1412.txt
# Deleted: dataset-v2/kaggle-good/archive\img840.txt
# Deleted: dataset-v2/kaggle-good/archive\img1006.txt
# Deleted: dataset-v2/kaggle-good/archive\img842.txt
# Deleted: dataset-v2/kaggle-good/archive\img959.txt
# Deleted: dataset-v2/kaggle-good/archive\img1425.txt
# Deleted: dataset-v2/kaggle-good/archive\img1008.txt
# Deleted: dataset-v2/kaggle-good/archive\img1073.txt
# Deleted: dataset-v2/kaggle-good/archive\img755.txt
# Deleted: dataset-v2/kaggle-good/archive\img877.txt
# Deleted: dataset-v2/kaggle-good/archive\img1374.txt
# Deleted: dataset-v2/kaggle-good/archive\img736.txt
# Deleted: dataset-v2/kaggle-good/archive\img1022.txt
# Deleted: dataset-v2/kaggle-good/archive\img1386.txt
# Deleted: dataset-v2/kaggle-good/archive\img1109.txt
# Deleted: dataset-v2/kaggle-good/archive\img1248.txt
# Deleted: dataset-v2/kaggle-good/archive\img768.txt
# Deleted: dataset-v2/kaggle-good/archive\img1300.txt
# Deleted: dataset-v2/kaggle-good/archive\img1226.txt
# Deleted: dataset-v2/kaggle-good/archive\img1390.txt
# Deleted: dataset-v2/kaggle-good/archive\img1206.txt
# Deleted: dataset-v2/kaggle-good/archive\img766.txt
# Deleted: dataset-v2/kaggle-good/archive\img1325.txt
# Deleted: dataset-v2/kaggle-good/archive\img1059.txt
# Deleted: dataset-v2/kaggle-good/archive\img1303.txt
# Deleted: dataset-v2/kaggle-good/archive\img1235.txt
# Deleted: dataset-v2/kaggle-good/archive\img1015.txt
# Deleted: dataset-v2/kaggle-good/archive\img1277.txt
# Deleted: dataset-v2/kaggle-good/archive\img1098.txt
# Deleted: dataset-v2/kaggle-good/archive\img1184.txt
# Deleted: dataset-v2/kaggle-good/archive\img1357.txt
# Deleted: dataset-v2/kaggle-good/archive\img893.txt
# Deleted: dataset-v2/kaggle-good/archive\img984.txt
# Deleted: dataset-v2/kaggle-good/archive\img1326.txt
# Deleted: dataset-v2/kaggle-good/archive\img835.txt
# Deleted: dataset-v2/kaggle-good/archive\img1079.txt
# Deleted: dataset-v2/kaggle-good/archive\img866.txt
# Deleted: dataset-v2/kaggle-good/archive\img742.txt
# Deleted: dataset-v2/kaggle-good/archive\img1328.txt
# Deleted: dataset-v2/kaggle-good/archive\img726.txt
# Deleted: dataset-v2/kaggle-good/archive\img1191.txt
# Deleted: dataset-v2/kaggle-good/archive\img1265.txt
# Deleted: dataset-v2/kaggle-good/archive\img964.txt
# Deleted: dataset-v2/kaggle-good/archive\img954.txt
# Deleted: dataset-v2/kaggle-good/archive\img898.txt
# Deleted: dataset-v2/kaggle-good/archive\img1039.txt
# Deleted: dataset-v2/kaggle-good/archive\img939.txt
# Deleted: dataset-v2/kaggle-good/archive\img897.txt
# Deleted: dataset-v2/kaggle-good/archive\img1295.txt
# Deleted: dataset-v2/kaggle-good/archive\img880.txt
# Deleted: dataset-v2/kaggle-good/archive\img951.txt
# Deleted: dataset-v2/kaggle-good/archive\img1066.txt
# Deleted: dataset-v2/kaggle-good/archive\img926.txt
# Deleted: dataset-v2/kaggle-good/archive\img1162.txt
# Deleted: dataset-v2/kaggle-good/archive\img1113.txt
# Deleted: dataset-v2/kaggle-good/archive\img913.txt
# Deleted: dataset-v2/kaggle-good/archive\img1340.txt
# Deleted: dataset-v2/kaggle-good/archive\img858.txt
# Deleted: dataset-v2/kaggle-good/archive\img1361.txt
# Deleted: dataset-v2/kaggle-good/archive\img743.txt
# Deleted: dataset-v2/kaggle-good/archive\img1024.txt
# Deleted: dataset-v2/kaggle-good/archive\img1377.txt
# Deleted: dataset-v2/kaggle-good/archive\img761.txt
# Deleted: dataset-v2/kaggle-good/archive\img963.txt
# Deleted: dataset-v2/kaggle-good/archive\img976.txt
# Deleted: dataset-v2/kaggle-good/archive\img1354.txt
# Deleted: dataset-v2/kaggle-good/archive\img1094.txt
# Deleted: dataset-v2/kaggle-good/archive\img1190.txt
# Deleted: dataset-v2/kaggle-good/archive\img744.txt
# Deleted: dataset-v2/kaggle-good/archive\img1003.txt
# Deleted: dataset-v2/kaggle-good/archive\img1083.txt
# Deleted: dataset-v2/kaggle-good/archive\img894.txt
# Deleted: dataset-v2/kaggle-good/archive\img1049.txt
# Deleted: dataset-v2/kaggle-good/archive\img1177.txt
# Deleted: dataset-v2/kaggle-good/archive\img989.txt
# Deleted: dataset-v2/kaggle-good/archive\img1438.txt
# Deleted: dataset-v2/kaggle-good/archive\img1046.txt
# Deleted: dataset-v2/kaggle-good/archive\img997.txt
# Deleted: dataset-v2/kaggle-good/archive\img801.txt
# Deleted: dataset-v2/kaggle-good/archive\img740.txt
# Deleted: dataset-v2/kaggle-good/archive\img941.txt
# Deleted: dataset-v2/kaggle-good/archive\img1036.txt
# Deleted: dataset-v2/kaggle-good/archive\img1203.txt
# Deleted: dataset-v2/kaggle-good/archive\img966.txt
# Deleted: dataset-v2/kaggle-good/archive\img1355.txt
# Deleted: dataset-v2/kaggle-good/archive\img1168.txt
# Deleted: dataset-v2/kaggle-good/archive\img925.txt
# Deleted: dataset-v2/kaggle-good/archive\img876.txt
# Deleted: dataset-v2/kaggle-good/archive\img1150.txt
# Deleted: dataset-v2/kaggle-good/archive\img1122.txt
# Deleted: dataset-v2/kaggle-good/archive\img1299.txt
# Deleted: dataset-v2/kaggle-good/archive\img994.txt
# Deleted: dataset-v2/kaggle-good/archive\img1000.txt
# Deleted: dataset-v2/kaggle-good/archive\img1270.txt
# Deleted: dataset-v2/kaggle-good/archive\img789.txt
# Deleted: dataset-v2/kaggle-good/archive\img870.txt
# Deleted: dataset-v2/kaggle-good/archive\img1399.txt
# Deleted: dataset-v2/kaggle-good/archive\img874.txt
# Deleted: dataset-v2/kaggle-good/archive\img1349.txt
# Deleted: dataset-v2/kaggle-good/archive\img722.txt
# Deleted: dataset-v2/kaggle-good/archive\img1112.txt
# Deleted: dataset-v2/kaggle-good/archive\img812.txt
# Deleted: dataset-v2/kaggle-good/archive\img836.txt
# Deleted: dataset-v2/kaggle-good/archive\img1052.txt
# Deleted: dataset-v2/kaggle-good/archive\img756.txt
# Deleted: dataset-v2/kaggle-good/archive\img1348.txt
# Deleted: dataset-v2/kaggle-good/archive\img1268.txt
# Deleted: dataset-v2/kaggle-good/archive\img1116.txt
# Deleted: dataset-v2/kaggle-good/archive\img788.txt
# Deleted: dataset-v2/kaggle-good/archive\img1334.txt
# Deleted: dataset-v2/kaggle-good/archive\img1071.txt
# Deleted: dataset-v2/kaggle-good/archive\img1341.txt
# Deleted: dataset-v2/kaggle-good/archive\img1397.txt
# Deleted: dataset-v2/kaggle-good/archive\img1289.txt
# Deleted: dataset-v2/kaggle-good/archive\img814.txt
# Deleted: dataset-v2/kaggle-good/archive\img793.txt
# Deleted: dataset-v2/kaggle-good/archive\img1223.txt
# Deleted: dataset-v2/kaggle-good/archive\img1296.txt
# Deleted: dataset-v2/kaggle-good/archive\img1309.txt
# Deleted: dataset-v2/kaggle-good/archive\img1020.txt
# Deleted: dataset-v2/kaggle-good/archive\img982.txt
# Deleted: dataset-v2/kaggle-good/archive\img1018.txt
# Deleted: dataset-v2/kaggle-good/archive\img1430.txt
# Deleted: dataset-v2/kaggle-good/archive\img759.txt
# Deleted: dataset-v2/kaggle-good/archive\img1424.txt
# Deleted: dataset-v2/kaggle-good/archive\img787.txt
# Deleted: dataset-v2/kaggle-good/archive\img902.txt
# Deleted: dataset-v2/kaggle-good/archive\img797.txt
# Deleted: dataset-v2/kaggle-good/archive\img1142.txt
# Deleted: dataset-v2/kaggle-good/archive\img1432.txt
# Deleted: dataset-v2/kaggle-good/archive\img929.txt
# Deleted: dataset-v2/kaggle-good/archive\img875.txt
# Deleted: dataset-v2/kaggle-good/archive\img1218.txt
# Deleted: dataset-v2/kaggle-good/archive\img1030.txt
# Deleted: dataset-v2/kaggle-good/archive\img1047.txt
# Deleted: dataset-v2/kaggle-good/archive\img1017.txt
# Deleted: dataset-v2/kaggle-good/archive\img1012.txt
# Deleted: dataset-v2/kaggle-good/archive\img1255.txt
# Deleted: dataset-v2/kaggle-good/archive\img1108.txt
# Deleted: dataset-v2/kaggle-good/archive\img731.txt
# Deleted: dataset-v2/kaggle-good/archive\img1095.txt
# Deleted: dataset-v2/kaggle-good/archive\img996.txt
# Deleted: dataset-v2/kaggle-good/archive\img807.txt
# Deleted: dataset-v2/kaggle-good/archive\img723.txt
# Deleted: dataset-v2/kaggle-good/archive\img979.txt
# Deleted: dataset-v2/kaggle-good/archive\img962.txt
# Deleted: dataset-v2/kaggle-good/archive\img1088.txt
# Deleted: dataset-v2/kaggle-good/archive\img1319.txt
# Deleted: dataset-v2/kaggle-good/archive\img946.txt
# Deleted: dataset-v2/kaggle-good/archive\img1252.txt
# Deleted: dataset-v2/kaggle-good/archive\img1204.txt
# Deleted: dataset-v2/kaggle-good/archive\img965.txt
# Deleted: dataset-v2/kaggle-good/archive\img956.txt
# Deleted: dataset-v2/kaggle-good/archive\img728.txt
# Deleted: dataset-v2/kaggle-good/archive\img863.txt
# Deleted: dataset-v2/kaggle-good/archive\img1164.txt
# Deleted: dataset-v2/kaggle-good/archive\img1229.txt
# Deleted: dataset-v2/kaggle-good/archive\img1121.txt
# Deleted: dataset-v2/kaggle-good/archive\img995.txt
# Deleted: dataset-v2/kaggle-good/archive\img927.txt
# Deleted: dataset-v2/kaggle-good/archive\img1144.txt
# Deleted: dataset-v2/kaggle-good/archive\img779.txt
# Deleted: dataset-v2/kaggle-good/archive\img1139.txt
# Deleted: dataset-v2/kaggle-good/archive\img1333.txt
# Deleted: dataset-v2/kaggle-good/archive\img896.txt
# Deleted: dataset-v2/kaggle-good/archive\img881.txt
# Deleted: dataset-v2/kaggle-good/archive\img1279.txt
# Deleted: dataset-v2/kaggle-good/archive\img1356.txt
# Deleted: dataset-v2/kaggle-good/archive\img1247.txt
# Deleted: dataset-v2/kaggle-good/archive\img813.txt
# Deleted: dataset-v2/kaggle-good/archive\img1089.txt
# Deleted: dataset-v2/kaggle-good/archive\img1148.txt
# Deleted: dataset-v2/kaggle-good/archive\img800.txt
# Deleted: dataset-v2/kaggle-good/archive\img1420.txt
# Deleted: dataset-v2/kaggle-good/archive\img1132.txt
# Deleted: dataset-v2/kaggle-good/archive\img776.txt
# Deleted: dataset-v2/kaggle-good/archive\img1155.txt
# Deleted: dataset-v2/kaggle-good/archive\img826.txt
# Deleted: dataset-v2/kaggle-good/archive\img823.txt
# Deleted: dataset-v2/kaggle-good/archive\img1077.txt
# Deleted: dataset-v2/kaggle-good/archive\img1057.txt
# Deleted: dataset-v2/kaggle-good/archive\img1080.txt
# Deleted: dataset-v2/kaggle-good/archive\img1146.txt
# Deleted: dataset-v2/kaggle-good/archive\img1037.txt
# Deleted: dataset-v2/kaggle-good/archive\img915.txt
# Deleted: dataset-v2/kaggle-good/archive\img1208.txt
# Deleted: dataset-v2/kaggle-good/archive\img1273.txt
# Deleted: dataset-v2/kaggle-good/archive\img732.txt
# Deleted: dataset-v2/kaggle-good/archive\img1153.txt
# Deleted: dataset-v2/kaggle-good/archive\img1199.txt
# Deleted: dataset-v2/kaggle-good/archive\img935.txt
# Deleted: dataset-v2/kaggle-good/archive\img1061.txt
# Deleted: dataset-v2/kaggle-good/archive\img1294.txt
# Deleted: dataset-v2/kaggle-good/archive\img1360.txt
# Deleted: dataset-v2/kaggle-good/archive\img944.txt
# Deleted: dataset-v2/kaggle-good/archive\img1264.txt
# Deleted: dataset-v2/kaggle-good/archive\img1082.txt
# Deleted: dataset-v2/kaggle-good/archive\img1038.txt
# Deleted: dataset-v2/kaggle-good/archive\img1275.txt
# Deleted: dataset-v2/kaggle-good/archive\img1409.txt
# Deleted: dataset-v2/kaggle-good/archive\img1311.txt
# Deleted: dataset-v2/kaggle-good/archive\img1197.txt
# Deleted: dataset-v2/kaggle-good/archive\img906.txt
# Deleted: dataset-v2/kaggle-good/archive\img970.txt
# Deleted: dataset-v2/kaggle-good/archive\img1084.txt
# Done.

# %%
# Check for empty or malformed label files (blank, wrong class id)
import os
dataset_dir = 'dataset-v2/kaggle-good/archive'
valid_class_ids = {'0', '1', '2'}
malformed_labels = []
for label_file in os.listdir(dataset_dir):
    if label_file.endswith('.txt'):
        label_path = os.path.join(dataset_dir, label_file)
        with open(label_path, 'r') as f:
            lines = f.readlines()
            if not lines:
                malformed_labels.append((label_file, 'empty'))
                continue
            first_line = lines[0].strip()
            if not first_line:
                malformed_labels.append((label_file, 'blank'))
                continue
            class_id = first_line.split()[0]
            if class_id not in valid_class_ids:
                malformed_labels.append((label_file, f'invalid class id: {class_id}'))
print(f"Malformed label files found: {len(malformed_labels)}")
if malformed_labels:
    for label_file, reason in malformed_labels[:10]:
        print(f"{label_file}: {reason}")
    for label_file, _ in malformed_labels:
        os.remove(os.path.join(dataset_dir, label_file))
# Out:
# Malformed label files found: 4
# img1228.txt: empty
# img357.txt: empty
# img460.txt: empty
# img589.txt: empty

# %%
# Delete images with no corresponding label file
import os
dataset_dir = 'dataset-v2/kaggle-good/archive'
image_exts = ['.jpg', '.jpeg']
image_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if os.path.splitext(f)[1].lower() in image_exts)
label_stems = set(os.path.splitext(f)[0] for f in os.listdir(dataset_dir) if f.endswith('.txt'))
no_label = image_stems - label_stems
print(f"Deleting {len(no_label)} image files with no matching label...")
for stem in no_label:
    for ext in image_exts:
        img_path = os.path.join(dataset_dir, stem + ext)
        if os.path.exists(img_path):
            os.remove(img_path)
            print(f"Deleted: {img_path}")
print("Done.")
# Out:
# Deleting 6 image files with no matching label...
# Deleted: dataset-v2/kaggle-good/archive\img589.jpg
# Deleted: dataset-v2/kaggle-good/archive\img1424.jpeg
# Deleted: dataset-v2/kaggle-good/archive\img1228.jpg
# Deleted: dataset-v2/kaggle-good/archive\img460.jpg
# Deleted: dataset-v2/kaggle-good/archive\img357.jpg
# Deleted: dataset-v2/kaggle-good/archive\img1132.jpeg
# Done.

# %%
# Visualize class distribution and check for imbalance
import matplotlib.pyplot as plt
from collections import Counter
import os
dataset_dir = 'dataset-v2/kaggle-good/archive'
class_map = {'0': 'First Degree Burn', '1': 'Second Degree Burn', '2': 'Third Degree Burn'}
class_counts = Counter()
for label_file in os.listdir(dataset_dir):
    if label_file.endswith('.txt'):
        with open(os.path.join(dataset_dir, label_file), 'r') as f:
            first_line = f.readline()
            if first_line:
                class_id = first_line.strip().split()[0]
                class_counts[class_id] += 1
labels = [class_map.get(cid, 'Unknown') for cid in class_counts.keys()]
counts = [class_counts[cid] for cid in class_counts.keys()]
plt.figure(figsize=(7,4))
plt.bar(labels, counts, color=['#fbbf24', '#f87171', '#6366f1'])
plt.title('Class Distribution')
plt.xlabel('Burn Severity Class')
plt.ylabel('Number of Images')
plt.show()
print('Class counts:', dict(zip(labels, counts)))
min_count = min(counts) if counts else 0
max_count = max(counts) if counts else 0
if max_count > 1.5 * min_count:
    print('Warning: Class imbalance detected! Consider resampling or using class weights.')
else:
    print('No significant class imbalance detected.')
# Out:
# Class counts: {'First Degree Burn': 532, 'Second Degree Burn': 488, 'Third Degree Burn': 201}
# Warning: Class imbalance detected! Consider resampling or using class weights.

# %% [markdown]
# Your class distribution shows some imbalance, especially with "Third Degree Burn" having fewer samples than the other classes. However, this level of imbalance is common in real-world datasets and does not make your dataset unusable.
#
# You can still proceed with training, but you should take steps to address the imbalance for better model performance and fairness. The two most common approaches are:
#
# Use class weights during model training (recommended for deep learning). This tells the model to pay more attention to underrepresented classes.
# Resample the dataset (oversample minority class or undersample majority classes), but this can sometimes lead to overfitting or loss of data.
# Recommendation:
# Continue with your training, but be sure to use class weights in your model's fit() call. This is easy to implement and effective for your situation.
