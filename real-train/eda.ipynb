# %%
total_images = sum(class_counts.values())
print(f"Total images across all classes: {total_images}")
# Out:
# Total images across all classes: 412

# %%
import os
import matplotlib.pyplot as plt

train_dir = r'../real-dataset/compiled/'
class_counts = {}

# Count images in each class folder
for class_id in ['0', '1', '2', '3', '4']:
    class_path = os.path.join(train_dir, class_id)
    if os.path.isdir(class_path):
        num_images = len([f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
        class_counts[class_id] = num_images
        print(f"Class {class_id}: {num_images} images")

# Plot class distribution
labels = [f'Class {k}' for k in class_counts.keys()]
sizes = list(class_counts.values())

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Class Distribution (by image count)')
plt.axis('equal')
plt.show()
# Out:
# Class 0: 132 images
# Class 1: 164 images
# Class 2: 61 images
# Class 3: 55 images
# Class 4: 133 images

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image

# Show example images per class
fig, axs = plt.subplots(1, 5, figsize=(20, 4))
for idx, class_id in enumerate(['0', '1', '2', '3', '4']):
    class_path = os.path.join(train_dir, class_id)
    img_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if img_files:
        img_path = os.path.join(class_path, img_files[0])
        img = Image.open(img_path)
        axs[idx].imshow(img)
        axs[idx].set_title(f'Class {class_id}')
        axs[idx].axis('off')
    else:
        axs[idx].set_title(f'Class {class_id}\n(No images)')
        axs[idx].axis('off')
plt.suptitle('Example Images per Class')
plt.show()
